# %% [markdown]
# <a href="https://colab.research.google.com/github/JonFeli/supervised-soup-project/blob/main/ColabTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mounting drive where the images are stored
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The below code cell is just to test out whether the images on drive can actually be accessed and loaded.

# %%
import os
image_folder = '/content/drive/MyDrive/ImageNetSubset'
print(os.listdir(image_folder))

from PIL import Image
image_path = os.path.join(image_folder, 'train', 'binder', 'n02840245_5028.JPEG')
print(image_path)
img = Image.open(image_path)

import matplotlib.pyplot as plt

plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# ['train', 'val']
# /content/drive/MyDrive/ImageNetSubset/train/binder/n02840245_5028.JPEG

# %%
# integrating github by cloning our repo
# !git clone https://github.com/JonFeli/supervised-soup-project.git
# Out:
# fatal: destination path 'supervised-soup-project' already exists and is not an empty directory.
# /content/supervised-soup-project

# %%
# %cd /content/supervised-soup-project
# Out:
# /content/supervised-soup-project

# %%
# to pull updates run this code:
# !git pull origin main
# Out:
# From https://github.com/JonFeli/supervised-soup-project
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# to push changes to github run this code:
# !git add .
# !git commit -m "Your message"
# !git push origin main
